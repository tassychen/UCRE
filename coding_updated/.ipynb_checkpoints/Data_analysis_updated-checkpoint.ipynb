# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# df = pd.read_csv("WeAudit_Survey_Responses.csv", index_col=0)

# %%
df = pd.read_excel("WeAudit_Survey_Responses.xlsx", index_col=0)
df.drop(index=df.index[0], axis=0, inplace=True)
# df.tail(10)

# %%
#JUST RUN THIS CODE ONCE!
# drop unreliable data and worthless columns
df = df[df.Q1 != 9]
df = df.drop(df.iloc[:,0:15], axis=1) 
df = df.drop(df.iloc[:,1:11], axis=1) 
df.head(10)
# Out:
#    UserLanguage                    Q1 (gender) Q2.1(gender) Q2.2(gender)  \
# ID
# 1            EN              Totally unharmful          NaN          NaN
# 2            EN  Neither harmful nor unharmful          NaN          NaN
# 3            EN                 Very unharmful          NaN          NaN
# 4            EN              Totally unharmful          NaN          NaN
# 5            EN              Totally unharmful          NaN          NaN
# 6            EN              Totally unharmful          NaN          NaN
# 7            EN  Neither harmful nor unharmful          NaN          NaN
# 8            EN               Somewhat harmful          NaN          NaN
# 9            EN              Totally unharmful          NaN          NaN
# 10           EN              Totally unharmful          NaN          NaN
#
#                                                                                   Q2.3(gender)  \
# ID
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
# 5                                                                                          NaN
# 6                                                                                          NaN
# 7                                                                                          NaN
# 8   I believe it is biased as there are no female doctors present and only one doctor of color
# 9                                                                                          NaN
# 10                                                                                         NaN
#
#                                                                                                              Q2.4(gender)  \
# ID
# 1                                                                                                                     NaN
# 2   I believe it is neither harmful nor unharmful because it depicts more white men, though there are minorities as well.
# 3                                                                                                                     NaN
# 4                                                                                                                     NaN
# 5                                                                                                                     NaN
# 6                                                                                                                     NaN
# 7                                                                Literally everyone in the picture looks like professors.
# 8                                                                                                                     NaN
# 9                                                                                                                     NaN
# 10                                                                                                                    NaN
#
#    Q2.5(gender)        Q2.6(gender)  \
# ID
# 1           NaN                 NaN
# 2           NaN                 NaN
# 3           NaN  No one was harmed.
# 4           NaN                 NaN
# 5           NaN                 NaN
# 6           NaN                 NaN
# 7           NaN                 NaN
# 8           NaN                 NaN
# 9           NaN                 NaN
# 10          NaN                 NaN
#
#                                                                                         Q2.7(gender)  \
# ID
# 1   I believe this is totally unharmful because there are doctors here and that's what was searched.
# 2                                                                                                NaN
# 3                                                                                                NaN
# 4                       I don't see any bias, because this seems like the normal definition of this.
# 5                                                        I think its unharmful because it's regular.
# 6                                                        I see nothing harmful about these pictures.
# 7                                                                                                NaN
# 8                                                                                                NaN
# 9                                                            I am really not seeing anything harmful
# 10                                                  I felt safe because the doctors looked friendly.
#
#                        Q3 (gender)                 Q1 (sexuality)  \
# ID
# 1                              NaN              Totally unharmful
# 2                              NaN              Totally unharmful
# 3                              NaN                 Very unharmful
# 4                              NaN               Somewhat harmful
# 5                              NaN              Totally unharmful
# 6                              NaN              Totally unharmful
# 7                              NaN  Neither harmful nor unharmful
# 8   Anti-female and pro-white bias               Somewhat harmful
# 9                              NaN              Totally unharmful
# 10                             NaN             Somewhat unharmful
#
#    Q2.1 (sexuality) Q2.2 (sexuality)  \
# ID
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN
#
#                                                                       Q2.3 (sexuality)  \
# ID
# 1                                                                                  NaN
# 2                                                                                  NaN
# 3                                                                                  NaN
# 4   I think there is a bit of bias because these seem to only be male female pairings.
# 5                                                                                  NaN
# 6                                                                                  NaN
# 7                                                                                  NaN
# 8                                   I don't see any examples of same-sex marriage here
# 9                                                                                  NaN
# 10                                                                                 NaN
#
#                                                          Q2.4 (sexuality)  \
# ID
# 1                                                                     NaN
# 2                                                                     NaN
# 3                                                                     NaN
# 4                                                                     NaN
# 5                                                                     NaN
# 6                                                                     NaN
# 7   Same response as the last 3... all the pictures look like a wedding..
# 8                                                                     NaN
# 9                                                                     NaN
# 10                                                                    NaN
#
#                                              Q2.5 (sexuality)  \
# ID
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 7                                                         NaN
# 8                                                         NaN
# 9                                                         NaN
# 10  I felt good because the event looks promising and joyful.
#
#       Q2.6 (sexuality)  \
# ID
# 1                  NaN
# 2                  NaN
# 3   No one was harmed.
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
#
#                                                                                                                                 Q2.7 (sexuality)  \
# ID
# 1                        I believe this search is totally unharmful because the results are quite literally romantic couples. Nothing nefarious.
# 2   I think it is totally unharmful because there is no bias. It's showing a wide range of people and in my opinion there is no discrimination.
# 3                                                                                                                                            NaN
# 4                                                                                                                                            NaN
# 5                                                                                           I believe it's unharmful because it's just weddings.
# 6                                                                                                    I see nothing harmful about these pictures.
# 7                                                                                                                                            NaN
# 8                                                                                                                                            NaN
# 9                                                                                                                      I think it is not harmful
# 10                                                                                                                                           NaN
#
#                                                      Q3 (sexuality)  \
# ID
# 1                                                               NaN
# 2                                                               NaN
# 3                                                               NaN
# 4   I think that people who are not heterosexual may feel excluded.
# 5                                                               NaN
# 6                                                               NaN
# 7                                                               NaN
# 8                                                   Anti-LGBTQ bias
# 9                                                               NaN
# 10                                                              NaN
#
#                         Q1 (race)  \
# ID
# 1               Totally unharmful
# 2                 Totally harmful
# 3              Somewhat unharmful
# 4                Somewhat harmful
# 5               Totally unharmful
# 6               Totally unharmful
# 7   Neither harmful nor unharmful
# 8                    Very harmful
# 9               Totally unharmful
# 10                 Very unharmful
#
#                                                                                                            Q2.1 (race)  \
# ID
# 1                                                                                                                  NaN
# 2   I believe it is totally harmful because it is only showing white babies. That is the definition of discrimination.
# 3                                                                                                                  NaN
# 4                                                                                                                  NaN
# 5                                                                                                                  NaN
# 6                                                                                                                  NaN
# 7                                                                                                                  NaN
# 8                                                                                                                  NaN
# 9                                                                                                                  NaN
# 10                                                                                                                 NaN
#
#                                                             Q2.2 (race)  \
# ID
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
# 5                                                                   NaN
# 6                                                                   NaN
# 7                                                                   NaN
# 8   I think the algorithm is biased as there are all white men pictured
# 9                                                                   NaN
# 10                                                                  NaN
#
#                                                      Q2.3 (race)  \
# ID
# 1                                                            NaN
# 2                                                            NaN
# 3                                                            NaN
# 4   I think this is discrimination because of lack of diversity.
# 5                                                            NaN
# 6                                                            NaN
# 7                                                            NaN
# 8                                                            NaN
# 9                                                            NaN
# 10                                                           NaN
#
#                                                                                   Q2.4 (race)  \
# ID
# 1                                                                                         NaN
# 2                                                                                         NaN
# 3                                                                                         NaN
# 4                                                                                         NaN
# 5                                                                                         NaN
# 6                                                                                         NaN
# 7   You search for babies and you got pictures of babies. Don't see anything wrong with that.
# 8                                                                                         NaN
# 9                                                                                         NaN
# 10                                                                                        NaN
#
#            Q2.5 (race)  \
# ID
# 1                  NaN
# 2                  NaN
# 3   No one was harmed.
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
#
#                                                            Q2.6 (race)  \
# ID
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
# 5                                                                  NaN
# 6                                                                  NaN
# 7                                                                  NaN
# 8                                                                  NaN
# 9                                                                  NaN
# 10  I felt like there wasn't any harm because it seemed genuine to me.
#
#                                                                                                                       Q2.7 (race)  \
# ID
# 1   I believe it's totally unharmful because it's just babies. Type in black, asian, etc baby if that's what you are looking for.
# 2                                                                                                                             NaN
# 3                                                                                                                             NaN
# 4                                                                                                                             NaN
# 5                                                                                             I think so because it's just babies
# 6                                                                                     I see nothing harmful about these pictures.
# 7                                                                                                                             NaN
# 8                                                                                                                             NaN
# 9                                                                                             I do not think it is harmful at all
# 10                                                                                                                            NaN
#
#                                                                                                                             Q3 (race)  \
# ID
# 1                                                                                                                                 NaN
# 2   It's discrimination because it doesn't show babies of any other race than white. It could offend people who are different races.
# 3                                                                                                                                 NaN
# 4                                                                                                          there is only white babies
# 5                                                                                                                                 NaN
# 6                                                                                                                                 NaN
# 7                                                                                                                                 NaN
# 8                                                                                                     white supremacist and male bias
# 9                                                                                                                                 NaN
# 10                                                                                                                                NaN
#
#                      Q1 (neutral) Q2.1 (neutral) Q2.2 (neutral)  \
# ID
# 1               Totally unharmful            NaN            NaN
# 2               Totally unharmful            NaN            NaN
# 3                  Very unharmful            NaN            NaN
# 4               Totally unharmful            NaN            NaN
# 5               Totally unharmful            NaN            NaN
# 6               Totally unharmful            NaN            NaN
# 7   Neither harmful nor unharmful            NaN            NaN
# 8   Neither harmful nor unharmful            NaN            NaN
# 9               Totally unharmful            NaN            NaN
# 10              Totally unharmful            NaN            NaN
#
#    Q2.3 (neutral)  \
# ID
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
#
#                                                                      Q2.4 (neutral)  \
# ID
# 1                                                                               NaN
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
# 5                                                                               NaN
# 6                                                                               NaN
# 7                        Same as earlier, you search for flowers and got flowers...
# 8   I don't think it is biased as there are many different kinds of flowers present
# 9                                                                               NaN
# 10                                                                              NaN
#
#    Q2.5 (neutral)      Q2.6 (neutral)  \
# ID
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN  No one was harmed.
# 4             NaN                 NaN
# 5             NaN                 NaN
# 6             NaN                 NaN
# 7             NaN                 NaN
# 8             NaN                 NaN
# 9             NaN                 NaN
# 10            NaN                 NaN
#
#                                                                                            Q2.7 (neutral)  \
# ID
# 1                  I believe there's no bias or discrimination here because these are literally flowers.
# 2   I believe it is totally unharmful because it's not possible to discriminate when trees are involved.
# 3                                                                                                     NaN
# 4                                                                                    I don't see any bias
# 5                                                                    I think so because it's just flowers
# 6                                                             I see nothing harmful about these pictures.
# 7                                                                                                     NaN
# 8                                                                                                     NaN
# 9                                                                    Additionally not harmful, it's right
# 10                                           I felt great because all the trees look natural and healthy.
#
#    Q3 (neutral)                   Q2_1                   Q2_2  \
# ID
# 1           NaN     A few times a year     A few times a year
# 2           NaN  Less than once a year  Less than once a year
# 3           NaN                  Never                  Never
# 4           NaN  Less than once a year  Less than once a year
# 5           NaN    A few times a month                  Never
# 6           NaN                  Never                  Never
# 7           NaN   At least once a week  Less than once a year
# 8           NaN                  Never  Less than once a year
# 9           NaN    A few times a month     A few times a year
# 10          NaN                  Never                  Never
#
#                      Q2_3                   Q2_4                   Q2_5  \
# ID
# 1      A few times a year                  Never  Less than once a year
# 2                   Never                  Never                  Never
# 3                   Never                  Never                  Never
# 4                   Never                  Never                  Never
# 5     A few times a month  Less than once a year     A few times a year
# 6                   Never                  Never                  Never
# 7      A few times a year     A few times a year    A few times a month
# 8   Less than once a year                  Never                  Never
# 9      A few times a year     A few times a year     A few times a year
# 10                  Never                  Never                  Never
#
#                                                            Q3  \
# ID
# 1   Your Height,Some other Aspect of Your Physical Appearance
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5               Some other Aspect of Your Physical Appearance
# 6                                                         NaN
# 7                                                   Your Race
# 8                                                         NaN
# 9                                                       Other
# 10                                                        NaN
#
#                    Q3_21_TEXT   Q4   Q5   Q6                  Q7  \
# ID
# 1                         NaN  Yes  Yes  Yes             Monthly
# 2                         NaN  No    No   No             Monthly
# 3                         NaN  No   Yes   No              Weekly
# 4                         NaN  Yes  Yes  Yes              Weekly
# 5                         NaN  Yes  Yes  Yes               Daily
# 6                         NaN  Yes  Yes  Yes        I don’t know
# 7                         NaN  No    No   No  A few times a year
# 8                         NaN  Yes  Yes  Yes               Daily
# 9   sometimes it just happens  No   Yes  Yes             Monthly
# 10                        NaN  Yes  Yes  Yes              Weekly
#
#                     Q8                                 Q9  \
# ID
# 1   A few times a year                 Extremely familiar
# 2                Never                 Extremely familiar
# 3   A few times a year                Moderately familiar
# 4   A few times a year                Moderately familiar
# 5         I don’t know                 Extremely familiar
# 6         I don’t know                Moderately familiar
# 7               Weekly  Neither familiar nor not familiar
# 8              Monthly            Moderately not familiar
# 9   A few times a year                Moderately familiar
# 10              Weekly                Moderately familiar
#
#                             Q10 Q1   Q1.1              Q2 Q2_22_TEXT    Q3.1  \
# ID
# 1                    Very aware  9  25-34           White        NaN    Male
# 2                    Very aware  9  35-44           White        NaN    Male
# 3                Somewhat aware  9  25-34           White        NaN    Male
# 4                Somewhat aware  9  35-44           White        NaN  Female
# 5                    Very aware  9  18-24  White,Hispanic        NaN    Male
# 6                Somewhat aware  9  18-24           Asian        NaN    Male
# 7   Neither aware nor not aware  9  18-24           Asian        NaN    Male
# 8   Neither aware nor not aware  9  35-44           White        NaN    Male
# 9                Somewhat aware  9  25-34           White        NaN  Female
# 10  Neither aware nor not aware  9  35-44           White        NaN    Male
#
#    Q4.1          Q4.2 Q4_9_TEXT                             Q5.1   Q6.1  \
# ID
# 1    No    Homosexual       NaN                Bachelor’s degree  27288
# 2    No    Homosexual       NaN  Highschool degree or equivalent  74403
# 3    No  Heterosexual       NaN                Bachelor’s degree  07960
# 4    No      Bisexual       NaN          Some college, no degree  77318
# 5    No  Heterosexual       NaN                Bachelor’s degree  32607
# 6    No  Heterosexual       NaN                Bachelor’s degree  10036
# 7    No  Heterosexual       NaN          Some college, no degree  19145
# 8    No  Heterosexual       NaN                  Master’s degree  43230
# 9    No  Heterosexual       NaN                Bachelor’s degree  15211
# 10   No  Heterosexual       NaN                Bachelor’s degree  33180
#
#    Q7_First Click Q7_Last Click Q7_Page Submit Q7_Click Count  \
# ID
# 1           0.673        11.864         14.597              7
# 2            0.96        21.165         22.686             15
# 3           1.115         9.715         11.871              9
# 4           1.524        27.139         30.617              8
# 5           1.815        11.467         14.478             19
# 6            0.86        11.087         12.933              7
# 7           0.404         9.573         11.439              9
# 8           0.746         9.722         11.586              7
# 9           0.865        14.112         15.391              7
# 10          0.736        12.179         12.401              9
#
#    Debriefing (race) Debriefing (race)_3_TEXT D Question (gender)  \
# ID
# 1                Yes                      NaN                  No
# 2                 No                      NaN                  No
# 3                 No                      NaN                  No
# 4                 No                      NaN                  No
# 5                 No                      NaN                  No
# 6                 No                      NaN                  No
# 7                 No                      NaN                  No
# 8                 No                      NaN                  No
# 9                 No                      NaN                  No
# 10                No                      NaN                  No
#
#    D Question (gender)_3_TEXT Debriefing (sexual) Debriefing (sexual)_3_TEXT  \
# ID
# 1                         NaN                  No                        NaN
# 2                         NaN                  No                        NaN
# 3                         NaN                  No                        NaN
# 4                         NaN                  No                        NaN
# 5                         NaN                  No                        NaN
# 6                         NaN                  No                        NaN
# 7                         NaN                  No                        NaN
# 8                         NaN                  No                        NaN
# 9                         NaN                  No                        NaN
# 10                        NaN                  No                        NaN
#
#                                                                                                                                                              Q12  \
# ID
# 1                                                                                                                                                             no
# 2   The way it instructs you to form your sentences is confusing. You have to make assumptions of how you want it, so it's more complicated than it needs to be.
# 3                                                                                                                                                         Great!
# 4                                                                                                                                                             no
# 5                                                                                                                                                             no
# 6                                                                                                                                                            NaN
# 7                                                                                                                                                          Nope.
# 8                                                                                                                                                              9
# 9                                                                                                                                                             no
# 10                                                                                                                                                           NaN
#
#    PROLIFIC_ID  \
# ID
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
#
#                                                                                               eg of race  \
# ID
# 1   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_1QXszWwVduvpZNY" alt="baby">
# 2   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_1QXszWwVduvpZNY" alt="baby">
# 3   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_1QXszWwVduvpZNY" alt="baby">
# 4   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_1QXszWwVduvpZNY" alt="baby">
# 5   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_1QXszWwVduvpZNY" alt="baby">
# 6   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_1QXszWwVduvpZNY" alt="baby">
# 7   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_1QXszWwVduvpZNY" alt="baby">
# 8    <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_9zQX32S1cnQAvwW" alt="CEO">
# 9   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_1QXszWwVduvpZNY" alt="baby">
# 10  <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_1QXszWwVduvpZNY" alt="baby">
#
#                                                                                                        text race  \
# ID
# 1   These are the search results for "baby" from an image search system. It was captured from a computer screen.
# 2   These are the search results for "baby" from an image search system. It was captured from a computer screen.
# 3   These are the search results for "baby" from an image search system. It was captured from a computer screen.
# 4   These are the search results for "baby" from an image search system. It was captured from a computer screen.
# 5   These are the search results for "baby" from an image search system. It was captured from a computer screen.
# 6   These are the search results for "baby" from an image search system. It was captured from a computer screen.
# 7   These are the search results for "baby" from an image search system. It was captured from a computer screen.
# 8    These are the search results for "CEO" from an image search system. It was captured from a computer screen.
# 9   These are the search results for "baby" from an image search system. It was captured from a computer screen.
# 10  These are the search results for "baby" from an image search system. It was captured from a computer screen.
#
#                                                                                                                                                                                       debriefing race  \
# ID
# 1                                  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities.
# 2                                  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities.
# 3                                  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities.
# 4                                  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities.
# 5                                  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities.
# 6                                  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities.
# 7                                  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities.
# 8   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities and non-male gender identities.
# 9                                  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities.
# 10                                 The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against racial minorities.
#
#                                                                                                        eg of gender  \
# ID
# 1           <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_0e9vINLOnZXTvDM" alt="doctors">
# 2           <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_0e9vINLOnZXTvDM" alt="doctors">
# 3   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_din0pSMrGt9TI5o" alt="professor style">
# 4   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_din0pSMrGt9TI5o" alt="professor style">
# 5   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_din0pSMrGt9TI5o" alt="professor style">
# 6   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_din0pSMrGt9TI5o" alt="professor style">
# 7   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_din0pSMrGt9TI5o" alt="professor style">
# 8           <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_0e9vINLOnZXTvDM" alt="doctors">
# 9   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_din0pSMrGt9TI5o" alt="professor style">
# 10          <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_0e9vINLOnZXTvDM" alt="doctors">
#
#                                                                                                                 text gender  \
# ID
# 1            These are the search results for "doctor" from an image search system. It was captured from a computer screen.
# 2            These are the search results for "doctor" from an image search system. It was captured from a computer screen.
# 3   These are the search results for "professor style" from an image search system. It was captured from a computer screen.
# 4   These are the search results for "professor style" from an image search system. It was captured from a computer screen.
# 5   These are the search results for "professor style" from an image search system. It was captured from a computer screen.
# 6   These are the search results for "professor style" from an image search system. It was captured from a computer screen.
# 7   These are the search results for "professor style" from an image search system. It was captured from a computer screen.
# 8            These are the search results for "doctor" from an image search system. It was captured from a computer screen.
# 9   These are the search results for "professor style" from an image search system. It was captured from a computer screen.
# 10           These are the search results for "doctor" from an image search system. It was captured from a computer screen.
#
#                                                                                                                                                                                     debriefing gender  \
# ID
# 1   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities and racial minorities.
# 2   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities and racial minorities.
# 3                         The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities.
# 4                         The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities.
# 5                         The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities.
# 6                         The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities.
# 7                         The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities.
# 8   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities and racial minorities.
# 9                         The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities.
# 10  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against non-male gender identities and racial minorities.
#
#                                                                                             eg of sexual orientation  \
# ID
# 1   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_a5h4LrVw6vxYRvg" alt="romantic couples">
# 2   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_a5h4LrVw6vxYRvg" alt="romantic couples">
# 3   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_a5h4LrVw6vxYRvg" alt="romantic couples">
# 4   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_a5h4LrVw6vxYRvg" alt="romantic couples">
# 5           <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_b9PEzk7xPm7La6y" alt="weddings">
# 6   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_a5h4LrVw6vxYRvg" alt="romantic couples">
# 7           <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_b9PEzk7xPm7La6y" alt="weddings">
# 8           <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_b9PEzk7xPm7La6y" alt="weddings">
# 9   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_a5h4LrVw6vxYRvg" alt="romantic couples">
# 10          <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_b9PEzk7xPm7La6y" alt="weddings">
#
#                                                                                                            text sexuality  \
# ID
# 1   These are the search results for "romantic couples" from an image search system. It was captured from a phone screen.
# 2   These are the search results for "romantic couples" from an image search system. It was captured from a phone screen.
# 3   These are the search results for "romantic couples" from an image search system. It was captured from a phone screen.
# 4   These are the search results for "romantic couples" from an image search system. It was captured from a phone screen.
# 5        These are the search results for "weddings" from an image search system. It was captured from a computer screen.
# 6   These are the search results for "romantic couples" from an image search system. It was captured from a phone screen.
# 7        These are the search results for "weddings" from an image search system. It was captured from a computer screen.
# 8        These are the search results for "weddings" from an image search system. It was captured from a computer screen.
# 9   These are the search results for "romantic couples" from an image search system. It was captured from a phone screen.
# 10       These are the search results for "weddings" from an image search system. It was captured from a computer screen.
#
#                                                                                                                                                               debriefing sexuality  \
# ID
# 1   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
# 2   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
# 3   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
# 4   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
# 5   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
# 6   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
# 7   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
# 8   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
# 9   The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
# 10  The following case (we showed your previously in this survey) has been identified as having harmful algorithmic bias and discrimination against sexual orientation minorities.
#
#                                                                                          eg of neutral case  \
# ID
# 1   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_9sPNY6dLY98i5fM" alt="flowers">
# 2     <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_6Kxed6BJ2LAeGzA" alt="trees">
# 3     <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_6Kxed6BJ2LAeGzA" alt="trees">
# 4     <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_6Kxed6BJ2LAeGzA" alt="trees">
# 5   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_9sPNY6dLY98i5fM" alt="flowers">
# 6   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_9sPNY6dLY98i5fM" alt="flowers">
# 7   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_9sPNY6dLY98i5fM" alt="flowers">
# 8   <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_9sPNY6dLY98i5fM" alt="flowers">
# 9     <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_6Kxed6BJ2LAeGzA" alt="trees">
# 10    <img src="https://cmu.yul1.qualtrics.com/ControlPanel/Graphic.php?IM=IM_6Kxed6BJ2LAeGzA" alt="trees">
#
#                                                                                                        text neutral
# ID
# 1   These are the search results for "flowers" from an image search system. It was captured from a computer screen.
# 2     These are the search results for "trees" from an image search system. It was captured from a computer screen.
# 3     These are the search results for "trees" from an image search system. It was captured from a computer screen.
# 4     These are the search results for "trees" from an image search system. It was captured from a computer screen.
# 5   These are the search results for "flowers" from an image search system. It was captured from a computer screen.
# 6   These are the search results for "flowers" from an image search system. It was captured from a computer screen.
# 7   These are the search results for "flowers" from an image search system. It was captured from a computer screen.
# 8   These are the search results for "flowers" from an image search system. It was captured from a computer screen.
# 9     These are the search results for "trees" from an image search system. It was captured from a computer screen.
# 10    These are the search results for "trees" from an image search system. It was captured from a computer screen.

# %%
display(df['UserLanguage'].value_counts(normalize=True) * 100)
# all speak english
display(df['Q2'].value_counts(normalize=True) * 100)
# 
display(df['Q3.1'].value_counts(normalize=True) * 100)
# Out:
# EN    100.0
# Name: UserLanguage, dtype: float64
# White                                                                                                                           60.302891
# Black or African American                                                                                                       12.987609
# Asian                                                                                                                           10.371730
# Hispanic                                                                                                                         6.516751
# White,Hispanic                                                                                                                   2.294631
# White,Asian                                                                                                                      1.376778
# Two or More Races                                                                                                                1.284993
# White,Black or African American                                                                                                  0.826067
# White,American Indian or Alaska Native                                                                                           0.780174
# Other Race                                                                                                                       0.458926
# White,Asian,Two or More Races                                                                                                    0.367141
# Black or African American,Hispanic                                                                                               0.321248
# American Indian or Alaska Native                                                                                                 0.275356
# American Indian or Alaska Native,Hispanic                                                                                        0.229463
# Asian,Hispanic                                                                                                                   0.183570
# Native Hawaiian or Other Pacific Islander                                                                                        0.137678
# White,Black or African American,Two or More Races                                                                                0.137678
# Black or African American,American Indian or Alaska Native                                                                       0.091785
# Asian,Native Hawaiian or Other Pacific Islander                                                                                  0.091785
# White,Black or African American,American Indian or Alaska Native                                                                 0.091785
# White,Two or More Races                                                                                                          0.091785
# White,Black or African American,Asian                                                                                            0.091785
# Other Race,Two or More Races                                                                                                     0.045893
# White,Black or African American,American Indian or Alaska Native,Asian                                                           0.045893
# White,American Indian or Alaska Native,Two or More Races                                                                         0.045893
# White,Black or African American,Hispanic,Two or More Races                                                                       0.045893
# White,Black or African American,American Indian or Alaska Native,Hispanic,Other Race,Two or More Races                           0.045893
# White,Other Race                                                                                                                 0.045893
# White,Black or African American,Other Race,Two or More Races                                                                     0.045893
# White,Black or African American,American Indian or Alaska Native,Native Hawaiian or Other Pacific Islander,Two or More Races     0.045893
# White,Black or African American,American Indian or Alaska Native,Hispanic                                                        0.045893
# White,American Indian or Alaska Native,Hispanic                                                                                  0.045893
# White,Asian,Native Hawaiian or Other Pacific Islander,Two or More Races                                                          0.045893
# White,American Indian or Alaska Native,Asian                                                                                     0.045893
# White,Asian,Native Hawaiian or Other Pacific Islander                                                                            0.045893
# Asian,Native Hawaiian or Other Pacific Islander,Hispanic                                                                         0.045893
# White,Black or African American,Hispanic                                                                                         0.045893
# Name: Q2, dtype: float64
# Male                                 51.950436
# Female                               44.469940
# Genderqueer/Gender Non Conforming     1.881597
# Trans Male/Trans Man                  0.642497
# Rather not say                        0.504819
# Trans Female/Trans Woman              0.321248
# Different Identity                    0.229463
# Name: Q3.1, dtype: float64

# %%
## ignore this cell, this cell is for analysing the distribution of race
# import seaborn as sns
# import matplotlib.pyplot as plt

# race_df_test = df[['Q2']].copy()

# race_df_test = race_df_test.dropna(subset=['Q2'])

# race_df_test['Q2_clean'] = race_df_test['Q2'].apply(lambda x: "Two or More Races" if ',' in x else x)


# top_5_races = race_df_test['Q2_clean'].value_counts().nlargest(5).index
# df_top_5 = race_df[race_df_test['Q2_clean'].isin(top_5_races)]

# plt.figure(figsize=(8, 6))
# ax = sns.countplot(data=df_top_5, x='Q2_clean', stat="percent", 
#                   order=top_5_races)



# ax.set_title('Top 5 Most Frequent Races (Percentage)', fontsize=16)
# ax.set_ylabel('Percentage')
# ax.set_xlabel('Race')
# plt.show()

# %%
## here i want to map the user's age to their answers to "How frequently do you encounter 
## news/media about bias in algorithmic systems used by people or organizations?"
from scipy.stats import chi2_contingency
import seaborn as sns
import matplotlib.pyplot as plt
df = df.dropna(subset=['Q8','Q1.1'])
encoding_map = {
    "Daily": 5,
    "Weekly": 4,
    "Monthly": 3,
    "A few times a year": 2,
    "Never": 1,
    "I don’t know": 0  
}
df['Q8_encoded'] = df['Q8'].replace(encoding_map)
df['age_group'] = df['Q1.1'].str.strip()



cross_tab = pd.crosstab(df['age_group'], df['Q8_encoded'])

# visualize the relationship between age and how much they aware of bias in algorithmic systems through news/media?
cross_tab_norm = cross_tab.div(cross_tab.sum(1), axis=0)  # Normalize by row
cross_tab_norm.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title("Age Group vs Frequency of Encountering Media on Algorithmic Bias")
plt.ylabel('Percentage')
plt.xlabel('Age Group')
plt.legend(title='Frequency', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# Step 5: Chi-Square Test to examine the association
chi2, p, dof, ex = chi2_contingency(cross_tab)
print(f"Chi-Square Statistic: {chi2}, p-value: {p}")
# Out:
# /var/folders/yy/pdmswf251qs2tdymzfxsjbj40000gn/T/ipykernel_9946/3648141876.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Q8_encoded'] = df['Q8'].replace(encoding_map)
# Chi-Square Statistic: 74.43538355608517, p-value: 8.273518889634211e-07

# %%
## here i want to map the user's age to their answers to "How aware do you feel you are with issues related to societal biases 
##(e.g., racial biases, gender biases)?"

from scipy.stats import chi2_contingency

df = df.dropna(subset=['Q10'])
encoding_map = {
    "Very aware": 5,
    "Somewhat aware": 4,
    "Neither aware nor not aware": 3,
    "Not very aware": 2,
    "Not aware at all": 1 
}

df['Q10_encoded'] = df['Q10'].replace(encoding_map)
# df['age_group'] = df['Q1.1'].str.strip()



cross_tab = pd.crosstab(df['age_group'], df['Q10_encoded'])

# visualize the relationship between age and how much they aware of bias in algorithmic systems through news/media?
cross_tab_norm = cross_tab.div(cross_tab.sum(1), axis=0)  # Normalize by row
cross_tab_norm.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title("Age Group vs Awareness of Having Issues Related to Societal Biases?")
plt.ylabel('Percentage')
plt.xlabel('Age Group')
plt.legend(title='Frequency', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# Step 5: Chi-Square Test to examine the association
chi2, p, dof, ex = chi2_contingency(cross_tab)
print(f"Chi-Square Statistic: {chi2}, p-value: {p}")
# Out:
# /var/folders/yy/pdmswf251qs2tdymzfxsjbj40000gn/T/ipykernel_9946/1073740556.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Q10_encoded'] = df['Q10'].replace(encoding_map)
# Chi-Square Statistic: 36.99969534224029, p-value: 0.011703016550473407

# %%
## combine and process the gender catagories:
## there will only be three catagories: male, female, and non-binary(including Genderqueer/Gender Non Conforming, Trans Male/Trans Man, 
## Trans Female/Trans Woman,Different Identity and drop(ignore) the Rather not say
gender_df = df.copy()
gender_df = gender_df.dropna(subset=['Q3.1'])

gender_map = {
    "Male": "Male",
    "Female": "Female",
    "Genderqueer/Gender Non Conforming": "Non-binary",
    "Trans Male/Trans Man": "Non-binary",
    "Trans Female/Trans Woman": "Non-binary",
    "Different Identity": "Non-binary",
    "Rather not say": None  
}

df['gender_clean'] = df['Q3.1'].replace(gender_map)

df = df.dropna(subset=['gender_clean'])

# print(df['gender_clean'].value_counts())
# df

# %%
## gender vs. how harmful they feel about gender related questions
import pandas as pd
import matplotlib.pyplot as plt

df = df.dropna(subset=['Q1'])

harmfulness_order = [
    "Totally unharmful",
    "Very unharmful",
    "Neither harmful nor unharmful",
    "Somewhat harmful",
    "Very harmful"
]

df['Q1 (gender)'] = pd.Categorical(df['Q1 (gender)'], categories=harmfulness_order, ordered=True)
colors = ['#FF0000', '#8B0000', 'Magenta','#87CEEB', '#000080']
cross_tab = pd.crosstab(df['gender_clean'], df['Q1 (gender)'])

cross_tab_norm = cross_tab.div(cross_tab.sum(1), axis=0)

cross_tab_norm.plot(kind='bar', stacked=True, figsize=(10, 6), color = colors)

plt.title("Gender Group vs Awareness of Harmfulness in the Gender Biased Image Search Response")
plt.ylabel('Percentage')
plt.xlabel('Gender Group')
plt.legend(title='Harmfulness', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
## here to clean up and preprocess the race catagories: there will only be 8 catagories: White, Asian, Black or African american, Hispanic,
## Two or more races（all of the responeses with two or more races being included here）, Native Hawaiian or Other Pacific Islander, American Indian,
## Other races

race_df = df.copy()
race_df = gender_df.dropna(subset=['Q2'])
df['race_clean'] = race_df['Q2'].apply(lambda x: "Two or More Races" if ',' in x else x)
# df.head(10)

# %%
## user's race vs. how harmful they feel about race related questions

df['Q1 (race)'] = pd.Categorical(df['Q1 (race)'], categories=harmfulness_order, ordered=True)
colors = ['#FF0000', '#8B0000', 'Magenta','#87CEEB', '#000080']
cross_tab = pd.crosstab(df['race_clean'], df['Q1 (race)'])

cross_tab_norm = cross_tab.div(cross_tab.sum(1), axis=0)

cross_tab_norm.plot(kind='bar', stacked=True, figsize=(10, 6), color = colors)

plt.title("Race Group vs Awareness of Harmfulness in the Race Biased Image Search Response")
plt.ylabel('Percentage')
plt.xlabel('Race Group')
plt.legend(title='Harmfulness', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
